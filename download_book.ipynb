# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
def scroll():
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    return

def load():
    bottom = driver.find_element_by_id('load_novel_p')
    bottom.click()
    scroll()
    return

def extract():
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    content = soup.find(id="BookText")
    
    f.write(content.get_text())
    return

# %%
links = ['https://umexpert.um.edu.my/.html',
        '',
        '',
        '',
        '']

# %%
driver = webdriver.Chrome()

# %%
base_url = 'https://www.qinxiaoshuo.com/book/%E5%85%AC%E7%88%B5%E5%AE%B6%E5%8D%83%E9%87%91%E5%A4%A7%E5%B0%8F%E5%A7%90%E7%9A%84%E7%88%B1%E5%A5%BD/#1'
f = open("公爵家千金大小姐的爱好吧.txt", "a+")

# %%
SCROLL_PAUSE_TIME = 3

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    scroll()

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# <ipython-input-47-3603bf903ff3> in <module>()
#      13
#      14     # Calculate new scroll height and compare with last scroll height
# ---> 15     new_height = driver.execute_script("return document.body.scrollHeight")
#      16     if new_height == last_height:
#      17         break
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
# ...

# %%
extract()

# %%
f = open("公爵家千金大小姐的爱好吧.txt", "r")
f.read()
# Out:
# '加载中，看轻小说就QinXiaoShuo.comweb版1-100试看\xa0\xa0转载信息\xa0\n转自公爵家千金大小姐的爱好吧\nhttp://tieba.baidu.com/f?kw=%E5%85%AC%E7%88%B5%E5%AE%B6%E5%8D%83%E9%87%91%E5%A4%A7%E5%B0%8F%E5%A7%90%E7%9A%84%E7%88%B1%E5%A5%BD&ie=utf-8&pn=0\n仅供个人学习交流使用，禁作商业用途\n下载后请在24小时内删除，本人不负担任何责任\n不可修改文本档，转载请务必向公爵家千金大小姐的爱好吧申请\n————————————————————\n\xa0web版1-100试看\xa0\xa0转载信息\xa0\n转自公爵家千金大小姐的爱好吧\nhttp://tieba.baidu.com/f?kw=%E5%85%AC%E7%88%B5%E5%AE%B6%E5%8D%83%E9%87%91%E5%A4%A7%E5%B0%8F%E5%A7%90%E7%9A%84%E7%88%B1%E5%A5%BD&ie=utf-8&pn=0\n仅供个人学习交流使用，禁作商业用途\n下载后请在24小时内删除，本人不负担任何责任\n不可修改文本档，转载请务必向公爵家千金大小姐的爱好吧申请\n————————————————————\n\xa0web版1-100试看\xa0\xa0转载信息\xa0\n转自公爵家千金大小姐的爱好吧\nhttp://tieba.baidu.com/f?kw=%E5%85%AC%E7%88%B5%E5%AE%B6%E5%8D%83%E9%87%91%E5%A4%A7%E5%B0%8F%E5%A7%90%E7%9A%84%E7%88%B1%E5%A5%BD&ie=utf-8&pn=0\n仅供个人学习交流使用，禁作商业用途\n下载后请在24小时内删除，本人不负担任何责任\n不可修改文本档，转载请务必向公爵家千金大小姐的爱好吧申请\n————————————————————\n\xa0web版1-100试看\xa0\xa0转载信息\xa0\n转自公爵家千金大小姐的爱好吧\nhttp://tieba.baidu.com/f?kw=%E5%85%AC%E7%88%B5%E5%AE%B6%E5%8D%83%E9
# ...

# %%
for i in range(1, 298):
    url = base_url + str(i)
    driver.get(url)
    

    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-10-583db9369dc3> in <module>()
#       6     content = soup.find(id="BookText")
#       7
# ----> 8     f.write(content.get_text())
#       9     time.sleep(5)
#
# UnsupportedOperation: not writable
