# %%
import sys
# !{sys.executable} -m pip install bs4
# Out:
# Processing /home/xunwei/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472/bs4-0.0.1-cp38-none-any.whl
# ...
#      |████████████████████████████████| 109 kB 1.7 MB/s eta 0:00:01
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import random

# %%
SCROLL_PAUSE_TIME = 3

def scroll_to_bottom():
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    return

def next_page():
#     <a class="pt-nextchapter" 
    bottom = driver.find_element_by_class_name('pt-nextchapter')
    bottom.click()
    scroll()
    return

def extract():
    # <div class="pt-read-cont" style="font-family: 微軟雅黑;">
    soup = BeautifulSoup(driver.page_source, 'html.parser')
#     content = soup.find(id="BookText")
    content = soup.find("div", class_="pt-read-cont")
    
    f.write(content.get_text(separator="\n\n"))
    return

# %%
base_url = 'https://www.twfanti.com/ShaoNianLuMingQuanWenMianFeiYueDu/read_1.html'

# https://www.qinxiaoshuo.com/tag/%E6%97%A5%E8%BD%BB/1.html

# %%
driver = webdriver.Chrome()
driver.get(base_url)

# %%
f = open("lu ming.txt", "a+")

for i in range(100):
    time.sleep(random.randint(2, 5))
    
    extract()
    next_page()
    
f.close()
# Out:
# 少年陸鳴全文免費閱讀 第420章 闖關
#
# 作者：小說陸鳴
# 分類：玄幻
# 更新時間：2019-12-13 01:55:56
#
#
#
#
#
#
# ...
